# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
ds_disk = xr.open_dataset("../data/Level1/L1_20220404.nc")

# %%
fig, ax = plt.subplots(figsize=(8, 6)) 
plt.plot(ds_disk['time'],ds_disk['hs'])
fig.tight_layout()
myFmt = mdates.DateFormatter('%d-%m')
ax.xaxis.set_major_formatter(myFmt)
plt.show()

# %%
ds_disk['time'][0]
# Out:
# <xarray.DataArray 'time' ()>
# array('2022-04-06T09:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 2022-04-06T09:00:00
# Attributes:
#     long_name:  time
